# %%
import pandas as pd

# %%
dataset = pd.read_excel("../Data/VehicleData.xlsx")

# %%
dataset.head()
# Out:
#   state  city_id city_name     fuel_type_org          fuel_type    class  \
# 0    CT     9015   Windham               UNK      Other/Unknown  Unknown
# 1    DE    10001      Kent              DIES     Diesel vehicle      Car
# 2    DE    10001      Kent              DIES     Diesel vehicle    Truck
# 3    DE    10001      Kent  ELECTRIC VEHICLE   Electric vehicle      Car
# 4    DE    10001      Kent               FFV  Flex fuel vehicle      Car
#
#    fifteen_Prct_in_jurisdiction  sixteen_Prct_in_jurisdiction  \
# 0                      0.000009                      0.000000
# 1                      0.000286                      0.000032
# 2                      0.001238                      0.001206
# 3                      0.000038                      0.000038
# 4                      0.007116                      0.003498
#
#    seventeen_Prct_in_jurisdiction  fifteen_wghtfuel_economy  \
# 0                        0.000000              0.000000e+00
# ...
